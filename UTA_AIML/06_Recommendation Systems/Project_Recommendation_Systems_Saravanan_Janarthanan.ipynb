# %% [markdown]
# # Project Recommendation Systems #
#
# ---
#
# DOMAIN: Smartphone, Electronics
# • CONTEXT: India is the second largest market globally for smartphones after China. About 134 million smartphones were sold across Indiain the year 2017 and is estimated to increase to about 442 million in 2022. India ranked second in the average time spent on mobile web bysmartphone users across Asia Pacific. The combination of very high sales volumes and the average smartphone consumer behaviour hasmade India a very attractive market for foreign vendors. As per Consumer behaviour, 97% of consumers turn to a search engine when theyare buying a product vs. 15% who turn to social media. If a seller succeeds to publish smartphones based on user’s behaviour/choice at theright place, there are 90% chances that user will enquire for the same. This Case Study is targeted to build a recommendation systembased on individual consumer’s behaviour or choice.
#
# DATA DESCRIPTION:
# - author : name of the person who gave the rating
# - country : country the person who gave the rating belongs to
# - data : date of the rating
# - domain: website from which the rating was taken from
# - extract: rating content
# - language: language in which the rating was given
# - product: name of the product/mobile phone for which the rating was given
# - score: average rating for the phone
# - score_max: highest rating given for the phone
# - source: source from where the rating was taken
#
# PROJECT OBJECTIVE: We will build a recommendation system using popularity based and collaborative filtering methods to recommend mobile phones to a user which are most popular and personalised respectively.

# %%
# Load the Libraries
import numpy  as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

class color:
   BOLD = '\033[1m'
   END = '\033[0m'

# %% [markdown]
# *** 1. Import the necessary libraries and read the provided CSVs as a data frame and perform the below steps. ***
#
# ***Q 1A. Merge all the provided CSVs into one dataFrame ***
#
# ***Ans 1A.***

# %%
# Load the libraries 
import glob
import os

# %%
# Read file with encoding to avoid parsing errors as content contains unicode or UTF-8 contents
filepath = 'RecommendationSystem'

combined_path = glob.glob(os.path.join(filepath, "phone_*.csv"))
df_of_file    = ( pd.read_csv( f, sep=',', encoding='latin1' ) for f in combined_path)
df_merged     = pd.concat(df_of_file, ignore_index=True)

# %%
df_merged.shape
# Out:
# (1415144, 14)

# %% [markdown]
# ***Q 1B. . Explore, understand the Data and share at least 2 observations.***
#
# ***Ans 2A.***

# %%
df_merged.head
# Out:
# <bound method NDFrame.head of                           Samsung Galaxy Note Edge (Black)  Unnamed: 1  \
# 0                                                      NaN         NaN
# 1                                                      NaN         NaN
# 2                                                      NaN         NaN
# 3                                                      NaN         NaN
# 4        Samsung Galaxy Note510.0149Motorola Smartphone...         NaN
# ...                                                    ...         ...
# 1415139                                                NaN         NaN
# 1415140                                                NaN         NaN
# 1415141                                                NaN         NaN
# 1415142                                                NaN         NaN
# 1415143                                                NaN         NaN
#
#          Unnamed: 2                          phone_url       date lang  \
# 0               NaN                                NaN        NaN  NaN
# 1               NaN                                NaN        NaN  NaN
# 2               NaN                                NaN        NaN  NaN
# 3               NaN                                NaN        NaN  NaN
# 4               NaN                                NaN        NaN  NaN
# ...             ...                                ...        ...  ...
# 1415139         NaN  /cellphones/alcatel-ot-club_1187/  5/12/2000   de
# 1415140         NaN  /cellphones/alcatel-ot-club_1187/  5/11/2000   de
# 1415141         NaN  /cellphones/alcatel-ot-club_1187/   5/4/2000   de
# 1415142         NaN  /cellphones/alcatel-ot-club_1187/   5/1/2000   de
# 1415143         NaN  /cellphones/alcatel-ot-club_1187/  4/25/2000   de
#
#         country source   domain  score  score_max  \
# 0           NaN    NaN      NaN    NaN        NaN
# 1           NaN    NaN      NaN    NaN        NaN
# 2           NaN    NaN      NaN    NaN        NaN
# 3           NaN    NaN      NaN    NaN        NaN
# 4           NaN    NaN      NaN    NaN        NaN
# ...         ...    ...      ...    ...        ...
# 1415139      de   Ciao  ciao.de    2.0       10.0
# 1415140      de   Ciao  ciao.de   10.0       10.0
# 1415141      de   Ciao  ciao.de    2.0       10.0
# 1415142      de   Ciao  ciao.de    8.0       10.0
# 1415143      de   Ciao  ciao.de    2.0       10.0
#
#                                                    extract        author  \
# 0                                                      NaN           NaN
# 1                                                      NaN           NaN
# 2                                                      NaN           NaN
# 3                                                      NaN           NaN
# 4                                                      NaN           NaN
# ...                                                    ...           ...
# 1415139  Weil mein Onkel bei ALcatel arbeitet habe ich ...    david.paul
# 1415140  Hy Liebe Leserinnen und Leser!! Ich habe seit ...  Christiane14
# 1415141  Jetzt hat wohl Alcatell gedacht ,sie machen wa...    michaelawr
# 1415142  Ich bin seit 2 Jahren (stolzer) Besitzer eines...   claudia0815
# 1415143  Was sich Alkatel hier wieder ausgedacht hat,sc...    michaelawr
#
#                          product
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1415139  Alcatel Club Plus Handy
# 1415140  Alcatel Club Plus Handy
# 1415141  Alcatel Club Plus Handy
# 1415142  Alcatel Club Plus Handy
# 1415143  Alcatel Club Plus Handy
#
# [1415144 rows x 14 columns]>

# %% [markdown]
# ***Observations***
# - There are 11 features in the csv file
# - The feature 'phone_url' needs to be trimmed or removed or hot encoded asthe orginal value does not provide any correlation to the data
# -  Simillarly the feature 'extract' is simillar to review comments and does not add added value or correlation
# - The features 'lang', 'country', 'source' and 'domain' needs to hot encoded with numerical values for better correlation

# %% [markdown]
# ***Q 1C. Round off scores to the nearest integers. ***
#
# ***Ans 1C.***

# %%
# find the median value
Scr_med_val = df_merged[ 'score' ].median( )
# Assign the median value to nulls
df_merged[ 'score' ].fillna( value = Scr_med_val, inplace = True )

# %%
# Check if there are any nulls or NA
df_merged['score'].isnull().sum()
# Out:
# 0

# %%
# Chaneg the datatype from float to int to round the value
df_merged['score'] = df_merged['score'].astype(int)

# %%
df_merged[ 'score' ].head()
# Out:
# 0    9
# 1    9
# 2    9
# 3    9
# 4    9
# Name: score, dtype: int32

# %% [markdown]
# *** Q 1D. Check for missing values. Impute the missing values, if any***
#
# ***Ans 1D***

# %%
# check the null values across the columns
df_merged.isnull().sum()
# Out:
# Samsung Galaxy Note Edge (Black)    1415138
# Unnamed: 1                          1415139
# Unnamed: 2                          1415139
# phone_url                                11
# date                                     11
# lang                                     11
# country                                  11
# source                                   11
# domain                                   11
# score                                     0
# score_max                             63500
# extract                               19372
# author                                63213
# product                                  12
# dtype: int64

# %%
# Score null values are already filled in.  Fill the the null score max feature of the row using the core value of the respective row
df_merged[ 'score_max' ].fillna( df_merged[ 'score' ] , inplace = True )

# %%
df_merged.isnull().sum()
# Out:
# Samsung Galaxy Note Edge (Black)    1415138
# Unnamed: 1                          1415139
# Unnamed: 2                          1415139
# phone_url                                11
# date                                     11
# lang                                     11
# country                                  11
# source                                   11
# domain                                   11
# score                                     0
# score_max                                 0
# extract                               19372
# author                                63213
# product                                  12
# dtype: int64

# %%
df_merged[ df_merged[ 'product' ].isnull() ]
# Out:
#                          Samsung Galaxy Note Edge (Black)  Unnamed: 1  \
# 0                                                     NaN         NaN
# 1                                                     NaN         NaN
# 2                                                     NaN         NaN
# 3                                                     NaN         NaN
# 4       Samsung Galaxy Note510.0149Motorola Smartphone...         NaN
# 5                                                     NaN         NaN
# 6                                    Samsung Galaxy Note5        10.0
# 7       Motorola Smartphone Motorola Moto X Desbloquea...        10.0
# 8       Motorola Smartphone Motorola Moto G Dual Chip ...        10.0
# 9       Nokia Smartphone Nokia Lumia 520 Desbloqueado ...        10.0
# 10      Samsung Smartphone Galaxy Win Duos Branco Desb...        10.0
# 802806                                                NaN         NaN
#
#         Unnamed: 2                          phone_url       date lang country  \
# 0              NaN                                NaN        NaN  NaN     NaN
# 1              NaN                                NaN        NaN  NaN     NaN
# 2              NaN                                NaN        NaN  NaN     NaN
# 3              NaN                                NaN        NaN  NaN     NaN
# 4              NaN                                NaN        NaN  NaN     NaN
# 5              NaN                                NaN        NaN  NaN     NaN
# 6            149.0                                NaN        NaN  NaN     NaN
# 7            134.0                                NaN        NaN  NaN     NaN
# 8            130.0                                NaN        NaN  NaN     NaN
# 9            128.0                                NaN        NaN  NaN     NaN
# 10           122.0                                NaN        NaN  NaN     NaN
# 802806         NaN  /cellphones/samsung-galaxy-s-iii/  1/22/2014   de      de
#
#         source     domain  score  score_max  \
# 0          NaN        NaN      9        9.0
# 1          NaN        NaN      9        9.0
# 2          NaN        NaN      9        9.0
# 3          NaN        NaN      9        9.0
# 4          NaN        NaN      9        9.0
# 5          NaN        NaN      9        9.0
# 6          NaN        NaN      9        9.0
# 7          NaN        NaN      9        9.0
# 8          NaN        NaN      9        9.0
# 9          NaN        NaN      9        9.0
# 10         NaN        NaN      9        9.0
# 802806  Amazon  amazon.de     10       10.0
#
#                                                   extract author product
# 0                                                     NaN    NaN     NaN
# 1                                                     NaN    NaN     NaN
# 2                                                     NaN    NaN     NaN
# 3                                                     NaN    NaN     NaN
# 4                                                     NaN    NaN     NaN
# 5                                                     NaN    NaN     NaN
# 6                                                     NaN    NaN     NaN
# 7                                                     NaN    NaN     NaN
# 8                                                     NaN    NaN     NaN
# 9                                                     NaN    NaN     NaN
# 10                                                    NaN    NaN     NaN
# 802806  Bestes Smartphone was ich bisher hatte :) Ã¶af...    NaN     NaN

# %% [markdown]
# ***Q 1E. Check for duplicate values and remove them, if any***
#
# ***Ans 1E***

# %%
# Use the drop_duplicates function to drop the duplicate rows
df_merged_wo_dup = df_merged.drop_duplicates()

# %%
# Check the dataframe after dropping the duplicate rows
df_merged_wo_dup.shape
# Out:
# (1408720, 14)

# %% [markdown]
# ***Q F. Keep only 1 Million data samples. Use random state=612.***
#
# ***Ans. 1F***
#
# Remove the records where the author value is null -  around 63K records
#
# Then take a sample of 1 Million records/ rows from remaining rows

# %%
df_merged_wo_dup.dropna( axis = 0, subset = [ 'author' ], inplace=True )

# %%
df_merged_wo_dup.shape
# Out:
# (1346896, 14)

# %%
# Use the sample function and specify the number or rows and the random state to maintain integrity across re-runs
df_merged_fin = df_merged_wo_dup.sample( n=1000000, random_state=612 )

# %%
df_merged_fin.shape
# Out:
# (1000000, 14)

# %% [markdown]
# ***Q 1G. Drop irrelevant features. Keep features like Author, Product, and Score***
#
# ***Ans 1G***
#
# drop 'phone_url' features as they dot influence the recommendation systems

# %%
# drop the feature phone_url 
df_merged_fin = df_merged_fin.drop( [ 'phone_url' ] , axis = 1 )

# %%
df_merged_fin.shape
# Out:
# (1000000, 13)

# %% [markdown]
# ----
#
# ***Q 2A Identify the most rated products.***
#
# ***Ans 2A.***

# %%
# Group by product and author to find the top rated product
most_rt_prd = df_merged_fin.groupby( 'product' )[ 'author' ].count( )
most_rt_prd.sort_values( ascending = False, inplace = True )
most_rt_prd.head( 10 )
# Out:
# product
# Lenovo Vibe K4 Note (White,16GB)                3839
# Lenovo Vibe K4 Note (Black, 16GB)               3205
# OnePlus 3 (Graphite, 64 GB)                     3013
# OnePlus 3 (Soft Gold, 64 GB)                    2666
# Samsung Galaxy Express I8730                    1997
# Huawei P8lite zwart / 16 GB                     1971
# Lenovo Vibe K5 (Gold, VoLTE update)             1905
# Samsung Galaxy S6 zwart / 32 GB                 1760
# Lenovo Vibe K5 (Grey, VoLTE update)             1542
# Lenovo Used Lenovo Zuk Z1 (Space Grey, 64GB)    1453
# Name: author, dtype: int64

# %% [markdown]
# ***Q 2B. Identify the users with most number of reviews***
#
# ***Ans 2B***

# %%
# Group by author vs product (score also can be used) to find the users providing most reviews
auth_most_num_rev = df_merged_fin.groupby( 'author' )[ 'product' ].count( )
auth_most_num_rev.sort_values(ascending = False, inplace = True)
auth_most_num_rev.head(10)
# Out:
# author
# Amazon Customer    57287
# Cliente Amazon     14348
# e-bit               6265
# Client d'Amazon     5706
# Amazon Kunde        3576
# Anonymous           2063
# einer Kundin        1905
# einem Kunden        1441
# unknown             1277
# Anonymous           1095
# Name: product, dtype: int64

# %% [markdown]
# ***Q 2C. Select the data with products having more than 50 ratings and users who have given more than 50 ratings. Report the shape of the final
# dataset.***
#
# ***Ans 2C.***

# %%
# Group by product and author agsint score to find the highest combonation of product and users (author) vs score
most_rt_prd1 = df_merged_fin.groupby( ['product', 'author' ] )[ 'score' ].count( )
most_rt_prd1.sort_values( ascending = False, inplace = True)
most_rt_prd1.head( 10 )
# Out:
# product                                       author
# Lenovo Vibe K4 Note (White,16GB)              Amazon Customer    2280
# Lenovo Vibe K4 Note (Black, 16GB)             Amazon Customer    1844
# OnePlus 3 (Graphite, 64 GB)                   Amazon Customer    1357
# OnePlus 3 (Soft Gold, 64 GB)                  Amazon Customer    1317
# Lenovo Vibe K5 (Gold, VoLTE update)           Amazon Customer    1189
# Lenovo Vibe K5 (Grey, VoLTE update)           Amazon Customer    1011
# Lenovo Used Lenovo Zuk Z1 (Space Grey, 64GB)  Amazon Customer     861
# YU Yuphoria YU5010A (Black+Silver)            Amazon Customer     664
# Lenovo Vibe K5 (Silver, 16GB)                 Amazon Customer     655
# OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)  Amazon Customer     626
# Name: score, dtype: int64

# %%
# filter the grouped data for review 
most_rt_prd_lst = most_rt_prd1[ most_rt_prd1 > 50].index.to_list()

# %%
len(most_rt_prd_lst)
# Out:
# 222

# %%
Df_flt_mot_rated = pd.DataFrame()

for val in most_rt_prd_lst:
    #print(val[0] + ' : ' + val[1])
    Df_flt_mot_rated = Df_flt_mot_rated.append( df_merged_fin[ (df_merged_fin['product'] == val[0] ) &  ( df_merged_fin['author'] == val[1]) ] )
    #print(Df_flt_mot_rated.shape)

# %%
# Report the shape of the final dataframe
Df_flt_mot_rated.shape
# Out:
# (40002, 13)

# %% [markdown]
# ----
#
# ***Q 3. Build a popularity based model and recommend top 5 mobile phones.**
#
# ***Ans 3.***

# %%
rcmd_mob_phn = pd.DataFrame( df_merged_fin.groupby( 'product' )[ 'score' ].mean() )

# %%
rcmd_mob_phn['scorecount'] = pd.DataFrame( df_merged_fin.groupby( 'product' )[ 'score' ].count() )

# %%
rcmd_mob_phn.sort_values(by=['score','scorecount'], ascending=[False, False] , inplace=True)
rcmd_mob_phn.head()
# Out:
#                                                     score  scorecount
# product
# Samsung Galaxy Note5                                 10.0         149
# Motorola Smartphone Motorola Moto X Desbloquead...   10.0         134
# Motorola Smartphone Motorola Moto G Dual Chip D...   10.0         130
# Nokia Smartphone Nokia Lumia 520 Desbloqueado O...   10.0         128
# Samsung Smartphone Galaxy Win Duos Branco Desbl...   10.0         122

# %% [markdown]
# ---
#
# ***Q 4.Build a collaborative filtering model using SVD. You can use SVD from surprise or build it from scratch(Note: Incase you’re building it from scratch you
# can limit your data points to 5000 samples if you face memory issues). Build a collaborative filtering model using kNNWithMeans from surprise. You
# can try both user-based and item-based model.***
#
# ***Ans 4.***

# %%
# Load the suprise nd KNNWithMeans libraries
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import train_test_split

# %%
df_red_sam = df_merged_fin.sample( n=50000, random_state=5 )

# %%
#Transform the data into SVD data format or map to SVD feature headers
reader = Reader(rating_scale=(1, 10))

svddata = Dataset.load_from_df(df_red_sam[['author', 'product', 'score']], reader)

# %%
#Split the svd dataset into training and test (75 : 25)
trainset, testset = train_test_split(svddata, test_size=.25, random_state=5 )

# %%
# Use item-based collaborative filtering
KNN_Mn_algo = KNNWithMeans(k=25, sim_options={'name': 'pearson_baseline', 'user_based': False})
KNN_Mn_algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# execute the model with the testset
test_pred = KNN_Mn_algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='Deacon', iid='Sony Ericsson Xperia X10 Mini', r_ui=10.0, est=5.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Ð\x95Ñ\x80Ð½Ð°Ð·Ð°Ñ\x80Ð¾Ð² Ð\x9cÐ¸Ñ\x85Ð°Ð¸Ð»', iid='Huawei Ascend Y511', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ian Fonseca', iid='OnePlus X (Onyx, 16GB)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Amazon Customer', iid='Apple iPhone 4S AT&T Cellphone, 16GB, Black', r_ui=10.0, est=7.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='vshalamay', iid='Nokia 6700 Classic', r_ui=4.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='sander1980', iid='Nokia 1100', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='knoocker', iid='Lenovo P780 4Gb', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Lori Burchall', iid='Samsung GT-I8190 S3 III Mini GSM Unlocked 8GB Android Smartphone - Gray - International Version No Warranty', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ð\x98Ð²Ð°Ð½Ð¾Ð² Ð\x95Ð²Ð³ÐµÐ½Ð¸Ð¹', iid='Sony Xperia Z Ultra (C6833)', r_ui=8.0, est=9.333333333333334, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Francisco Javier Vazquez', iid='LG G3 - Smartphone libre Android (pantalla 5.5", cÃ¡mara 13 Mp, 16 GB, Quad-Core 2.5 GHz, 2 GB RAM), gris titanio', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='tre34', iid='Sidekick Slide', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='TNO', iid='Samsung Galaxy W i8150 Zwart', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(u
r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Cliente Amazon', iid='Microsoft A00024282 - Smartphone (1 GB de RAM, 8 GB de memoria interna, WiFi, Dual SIM, Windows 8.1) color blanco', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='darakza', iid='SÃ\x83Â\xad Nokia 6310i', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Felipe', iid='Smartphone Asus Zenfone 3 ZE520KL-1B091BR Octa Core, Android 6, Tela 5.2Â´, 16GB, 16MP, 4G, Dual Chip Desbloqueado - Branco', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='oriuccia86', iid='Nokia 7100 Supernova', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Amazon Customer', iid='Lenovo Vibe S1 (4G, Dark Blue)', r_ui=6.0, est=6.760916792653463, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='FÃ\xa0bio', iid='Sony Xperia E5 Smartphone, Display 5" IPS, Memoria Interna 16 GB, 1.5 GB RAM, Processore Quad-Core, Nero', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Romulo Chirinos', iid='ZTE Warp Android Smartphone (Boost Mobile)', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ð¡Ð²ÐµÑ\x82Ð»Ð°Ð½Ð°', iid='Samsung Galaxy Win I8552 Titanium Grey 001', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Daniel.moskva', iid='Nokia 1616', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Pitchvlador007', iid='Nokia Lumia 920 Smartphone Windows Noir', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ð\x90Ð½Ñ\x8f', iid='LG X power (Ð¸Ð½Ð´Ð¸Ð³Ð¾)', r_ui=9.0, est=9.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Godssorcerer', iid='LG Electronics G4 Smartphone 14 cm (5,5 Zoll) (Touch-Display, 32 GB Speicher, Android 6) braune Lederversion', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='harryhou ', iid='Samsung Galaxy S6 edge 32GB (T-Mobile)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Happy', iid='TTfone Dual 2 (TT59) Basic Simple Senior Mobile Phone with Big Buttons, SOS Button, Large Display, Dual Sim', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Howard', iid='Apple iPhone 6 16GB Factory Unlocked GSM 4G LTE Internal Smartphone - Space Gray', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Louis', iid='Samsung Behold T919 Unlocked Quadband Phone with 3G Support, GPS and 5MP Camera - US Warranty - Rose Pink', r_ui=6.0, est=6.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='PATERMD', iid='Nokia 5800 Xpress Music', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Tobias B.', iid='Sony Xperia Z3 Compact Smartphone (11,7 cm (4,6 Zoll) HD-TRILUMINOS-Display, 2,5 GHz-Quad-Core-Prozessor, 20,7 Megapixel-Kamera, Android 4.4) mandarinrot', r_ui=10.0, est=2.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Juan Carlos', iid='Sony Xperia Z5 Premium - Smartphone de 5.5" (Bluetooth, WiFi, Qualcomm 810, procesador de 64 bits y 8 nÃºcleos, 3 GB de RAM, 32 GB, Android 5.1 Lollipop) color dorado', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='BenQ', iid='Motorola Moto G (3rd Generation) - Black - 16 GB - Global GSM Unlocked Phone', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='christine', iid='Huawei Ascend Y530 NOIR', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='tyeisha', iid='Samsung Admire Prepaid Android Phone, White (MetroPCS)', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ð\x94Ð¸Ð¼Ð°ÐºÑ\x80Ð°Ñ\x82', iid='Sony Ericsson K750i', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='aethersamples', iid='Microsoft Lumia 640 XL Dual-SIM LTE Smartphone (14,5 cm (5,7 Zoll) HD-LCD-Display, 1,2-GHz-Quad-Core-Prozessor, 13 Megapixel-Kamera, 3000 mAh Akku, 3G & 4G LTE, Dual-SIM, Windows Phone 8.1) schwarz', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid="Client d'Amazon", iid='Honor 8 Smartphone dÃ©bloquÃ© 4G (Ecran: 5,2 pouces - 32 Go - Double Nano-SIM - Android 6.0) Blanc NacrÃ©', r_ui=10.0, est=8.956685612254981, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='AnnaW', iid='Samsung Ð\x9cÐ¾Ð±Ð¸Ð»Ñ\x8cÐ½Ñ\x8bÐ¹ Ñ\x82ÐµÐ»ÐµÑ\x84Ð¾Ð½ Samsung SM-B310E Piton Duos', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='smartnasty', iid='Nokia E5', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='yamaha', iid='Samsung Galaxy S3 I9300 Blanco Libre', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='
details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='douglas', iid='Nokia X2-01', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='manuolivier', iid='Apple iPhone 6 64Go Gris SidÃ©ral', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='alexeiane', iid='SONY Xperia E1 Purple', r_ui=9.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Allbreezy ', iid='Samsung Galaxy S7 32GB (Sprint)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Matthew Jay Arrington', iid='Samsung Galaxy Ring (Virgin Mobile)', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Phoenix', iid='Blackberry Storm', r_ui=9.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Cliente Amazon', iid='Alcatel Onetouch 2004G - MÃ³vil libre de 2.4" (Chipset M6260A) color negro', r_ui=10.0, est=10, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='marcus leandro', iid='Samsung Smartphone Samsung Galaxy S Duos 2 Dual Chip Desbloqueado Android 4.2...', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='gedeone84', iid='Benefon Twin Dual SIM', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Beto31 ', iid='Samsung Galaxy S4 16GB (T-Mobile)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='kiki8711', iid='Nokia 6086', r_ui=4.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='sorry if my question is stupid.', iid='Sidekick AT&T QuickFire', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Juan Portillo', iid="Blackview 'Blackview Bv5000 5.0 4 G Outdoor Smartphone IP67 resistente al agua resistente al polvo antigolpes resistente, Android 5.1 doble cÃ¡maras de doble SIM", r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='nen Reiner Zocker', iid='Apple iPhone 3Gs Smartphone (8,9 cm (3,5 Zoll) Display, Touchscreen, 3 Megapixel Kamera, 16GB interne Speicher) schwarz', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='mandre', iid='Alcatel onetouch 991D Smartphone (10,2 cm (4 Zoll) Touchscreen, 3,2 Megapixel Kamera, Dual SIM, Android 2.3) schwarz', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Mace', iid='TigerKing THL W200 MTK6589T 1.5GHz Quad Core 1G RAM+8G ROM Android 4.2 1280*720 Touch Screen GPS WIFI (Black, White)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='e-bit', iid='Smartphone Samsung Galaxy J2 SM-J200M', r_ui=10.0, est=8.360169713251002, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='Amandine Chauviteau', iid='Samsung I9195 Galaxy S 4 MINI NFC LTE Smartphone Compact', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Toni L', iid='Acer Liquid E2 Duo - Smartphone libre (pantalla tÃ¡ctil de 4,5", cÃ¡mara 8 Mp, 4 procesadores de 1.2 GHz, 1 GB de RAM, dual SIM), blanco [importado]', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='e-bit', iid='Motorola Moto G 4 XT1626', r_ui=10.0, est=7.762318627798974, details={'actual_k': 25, 'was_impossible': False}),
#  Prediction(uid='miatamania', iid='Nokia 5610 Cep Telefonu', r_ui=9.0, est=9.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='JOSE VAZQUEZ', iid='Lenovo A916 4G Unlocked Smartphone (gift-16GB TF Card) 5.5 inch Android 4.4 MT6592M+6290 Octa 8 Core 1.4GHz 1GB 8GB 13MP Dual SIM FDD-LTE & WCDMA & GSM (Black+ 16GB TF Card)', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Christianne', iid='Honor 6 4G UK Smartphone (5 inch, Touchscreen, Octa-Core, 3GB RAM, 16GB ROM, 13MP rear camera, 5MP front camera, LTE CAT6, Android 4.4, Emotion UI 2.3) White', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='LOVELYJI', iid='Samsung Galaxy J7 Prime', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='sfat', iid='Nokia E5', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Yngrid Cuesta', iid='BLU Life Pure XL Full HD, 16MP, (32 GB+3GB RAM) - Factory Unlocked ("White")', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Natalie', iid='BLU Studio 5.5 D610a Unlocked Dual SIM GSM Phone (Pink)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  ...]

# %%
# Use user-based collaborative filtering
KNN_Mn_algo = KNNWithMeans(k=20, sim_options={'name': 'pearson_baseline', 'user_based': True})
KNN_Mn_algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# execute the model with the testset
test_pred = KNN_Mn_algo.test(testset)

# %%
test_pred
# Out:
# [Prediction(uid='Deacon', iid='Sony Ericsson Xperia X10 Mini', r_ui=10.0, est=10, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Ð\x95Ñ\x80Ð½Ð°Ð·Ð°Ñ\x80Ð¾Ð² Ð\x9cÐ¸Ñ\x85Ð°Ð¸Ð»', iid='Huawei Ascend Y511', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='
details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='ABHISHEK PATHAK', iid='Lenovo Vibe K4 Note (White,16GB)', r_ui=4.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Amy4 ', iid='Apple iPhone 5s 32 Gt â\x80\x90puhelin, hopea (lukitsematon), ME436', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='ralph jones', iid='ZTE T-Mobile Concord V768 Cell Phone - Blue', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='andrew2875', iid='Nokia E6', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='tatiany de jesus ...', iid='Smartphone Motorola Razr XT910', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Joe Strobel', iid='LG G2 D802 16GB Factory Unlocked International Version BLACK - No Warranty', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Skebeau', iid='Apple iPhone 6s', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Jonathan', iid='Huawei Ascend Y550 Smartphone (11,4 cm (4,5 Zoll) IPS-Display, 5 Megapixel-Kamera, 4GB Interner Speicher, Android 4.4) schwarz', r_ui=6.0, est=5.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Antonino Esposito', iid='Huawei Smartphone Huawei Ascend G 1, touchscreen 10,9 cm (4,3 pollici), fotocamera 8 megapixel, Android 4.0, colore: bianco', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ð\x9aÐ°Ñ\x80Ð¼Ð°Ð»Ñ\x8c Ð\x91Ð°Ð±Ñ\x80Ð°Ðº', iid='HTC Desire 816', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Cliente Amazon', iid='Microsoft A00024282 - Smartphone (1 GB de RAM, 8 GB de memoria interna, WiFi, Dual SIM, Windows 8.1) color blanco', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='darakza', iid='SÃ\x83Â\xad Nokia 6310i', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Felipe', iid='Smartphone Asus Zenfone 3 ZE520KL-1B091BR Octa Core, Android 6, Tela 5.2Â´, 16GB, 16MP, 4G, Dual Chip Desbloqueado - Branco', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='oriuccia86', iid='Nokia 7100 Supernova', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Amazon Customer', iid='Lenovo Vibe S1 (4G, Dark Blue)', r_ui=6.0, est=6.750963860731277, details={'actual_k': 20, 'was_impossible': False}),
#  Prediction(uid='FÃ\xa0bio', iid='Sony Xperia E5 Smartphone, Display 5" IPS, Memoria Interna 16 GB, 1.5 GB RAM, Processore Quad-Core, Nero', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Romulo Chirinos', iid='ZTE Warp Android Smartphone (Boost Mobile)', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ð¡Ð²ÐµÑ\x82Ð»Ð°Ð½Ð°', iid='Samsung Galaxy Win I8552 Titanium Grey 001', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Daniel.moskva', iid='Nokia 1616', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Pitchvlador007', iid='Nokia Lumia 920 Smartphone Windows Noir', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ð\x90Ð½Ñ\x8f', iid='LG X power (Ð¸Ð½Ð´Ð¸Ð³Ð¾)', r_ui=9.0, est=8.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Godssorcerer', iid='LG Electronics G4 Smartphone 14 cm (5,5 Zoll) (Touch-Display, 32 GB Speicher, Android 6) braune Lederversion', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='harryhou ', iid='Samsung Galaxy S6 edge 32GB (T-Mobile)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Happy', iid='TTfone Dual 2 (TT59) Basic Simple Senior Mobile Phone with Big Buttons, SOS Button, Large Display, Dual Sim', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Howard', iid='Apple iPhone 6 16GB Factory Unlocked GSM 4G LTE Internal Smartphone - Space Gray', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Louis', iid='Samsung Behold T919 Unlocked Quadband Phone with 3G Support, GPS and 5MP Camera - US Warranty - Rose Pink', r_ui=6.0, est=8.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='PATERMD', iid='Nokia 5800 Xpress Music', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Tobias B.', iid='Sony Xperia Z3 Compact Smartphone (11,7 cm (4,6 Zoll) HD-TRILUMINOS-Display, 2,5 GHz-Quad-Core-Prozessor, 20,7 Megapixel-Kamera, Android 4.4) mandarinrot', r_ui=10.0, est=6.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Juan Carlos', iid='Sony Xperia Z5 Premium - Smartphone de 5.5" (Bluetooth, WiFi, Qualcomm 810, procesador de 64 bits y 8 nÃºcleos, 3 GB de RAM, 32 GB, Android 5.1 Lollipop) color dorado', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid
', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Anonymous ', iid='Samsung Galaxy S7 edge 32GB (Sprint)', r_ui=10.0, est=9.464880761291525, details={'actual_k': 16, 'was_impossible': False}),
#  Prediction(uid='Anonymous', iid='Sanyo SCP-3100', r_ui=7.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='mark k.', iid='Apple iPhone 4 16GB SIM-Free - Black', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='TLang', iid='Sony Xperia Z5 Compact Smartphone (4,6 Zoll (11,7 cm) Touch-Display, 32 GB interner Speicher, Android 5.1) schwarz', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='kornishon', iid='Samsung a107 Prepaid GoPhone (AT&T)', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Dan', iid='Apple iPhone 5 - 16GB Black - SIM Free', r_ui=10.0, est=6.3, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='jessika Wegscheider', iid='Samsung C3300 Hello Kitty Edition Handy (Ohne Branding, 6,1 cm (2,4 Zoll) Display, Touchscreen, 1,3 Megapixel Kamera) weiÃ\x9f-pink', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Raman', iid='OnePlus 3T (Gunmetal, 6GB RAM + 64GB memory)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Mike', iid='Samsung Galaxy Ace 2 I8160 Smartphone (9,7 cm (3,8 Zoll) Touchscreen, Dual-Core, 800MHz, 768MB RAM, 4GB, 5 Megapixel Kamera, Android 2.3) ohne NFC wei??', r_ui=10.0, est=7.222222222222222, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='manoj gupta', iid='OPPO Digital F1 Plus (Gold, 4GB)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Carvalho', iid='Samsung Galaxy S II LTE', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='john pennington', iid='Samsung Galaxy Reverb (Virgin Mobile)', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='C.Klein', iid='Honor 6 Smartphone (5 Zoll, Touchscreen, Octa-Core, 3GB RAM, 16GB ROM, 13MP Hauptkamera, 5MP Frontkamera, LTE CAT6, Android 4.4, EmotionUI 2.3) weiÃ\x9f', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Leah', iid='Apple iPhone 4S MD865LL/A CDMA / GSM - Smartphone, 16GB (Black)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='GURIB', iid='Samsung Star GT-S5230', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='serg.siduk', iid='Samsung DuoS SGH-D880', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='vivek y. bhatkande', iid='Lenovo Vibe K4 Note (White,16GB)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Blondy4598 ', iid='Samsung Galaxy S6 edge+ 32GB (Verizon)', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Danne 406', iid='HTC One X 32GB', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Brandon Heemer', iid='Huawei Ascend W1 - Windows 8 Smartphone - Unlocked', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='M. Pfaff', iid='Microsoft Nokia X3-02 Handy (Ohne Branding, 6,1 cm (2,4 Zoll) Display, Touchscreen, 5 Megapixel Kamera) pink', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='James Von Doom', iid='Samsung Galaxy S6 G920F 32GB Factory Unlocked GSM 4G LTE Octa-Core Smartphone - Blue Topaz', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Amazon-Kunde', iid='Samsung Galaxy Trend Plus Smartphone (10,1 cm (4 Zoll) TFT-Display, 1,2GHz Prozessor, 786MB RAM, 5 Megapixel Kamera, 4GB interne Speicher, Android 4.2.2) schwarz', r_ui=10.0, est=6.461538461538462, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Tyco ', iid='Samsung Galaxy S7 edge 32GB (T-Mobile)', r_ui=9.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Cliente Amazon', iid='Samsung Galaxy A5 2016 Smartphone LTE, 16GB, Nero', r_ui=8.0, est=10, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='TheDude', iid='Sony Ericsson Xperia mini pro SK17a Unlocked Phone--U.S. Warranty (Black)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Vanessa M??nch', iid='Huawei Ascend P1 Smartphone (10,9 cm (4,3 Zoll) Touchscreen, 8 Megapixel Kamera, 4 GB Interner Speicher, Android 4.0) schwarz', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Sunny', iid='Sony Xperia S Smartphone (10,9 cm (4,3 Zoll) Touchscreen, Dual Core, 1,5GHz, 1GB RAM, 32GB eMMC, 12,1 Megapixel Kamera, Android 4.0) silber-grau', r_ui=10.0, est=8.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Federico Selli', iid='SLP Apple iPhone 5C, sbloccato 4 G (ricondizionato certificato grado A)', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='
- Black', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ð\x9cÐ¸Ñ\x88Ð°Ð½Ñ\x8f', iid='LG X power (Ð·Ð¾Ð»Ð¾Ñ\x82Ð¸Ñ\x81Ñ\x82Ñ\x8bÐ¹)', r_ui=9.0, est=10, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Wim O', iid='Nokia Lumia 710 zwart / 8 GB', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ivica P.', iid='Samsung Galaxy A5 (2017) Smartphone, 13,22 cm (5,2 Zoll) Display, LTE (4G)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='vovkulaka', iid='Nokia 5530 XpressMusic', r_ui=8.0, est=10, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='petrasimov', iid='HTC Wildfire S', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='RB', iid='Motorola Moto X (2 Generazione) Smartphone, Display 5,2 pollici Full HD, Fotocamera 13 MP, Processore Quad-Core...', r_ui=8.0, est=8.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Norbert Aknin', iid='Samsung GT B2100 TÃ©lÃ©phone portable GSM/EDGE Bluetooth Noir', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Amazon Customer', iid='Samsung 5-Feet Micro-USB 3.0 Charging Data Cable for Galaxy S5 and Note 3 N9000 - Non-Retail Packaging - White', r_ui=2.0, est=7.010813352139163, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Valter Morelli', iid='BQ Aquaris E4.5 - Smartphone libre Android (pantalla 4.5 pulgadas, cÃ¡mara 8 Mp, 8 GB, Quad-Core 1.3 GHz, 1 GB RAM, Android 4.4 KitKat), blanco y negro', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='chris', iid='Sony Xperia Z5 Compact Smartphone (4,6 Zoll (11,7 cm) Touch-Display, 32 GB interner Speicher, Android 5.1) schwarz', r_ui=8.0, est=8.5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='kamaleshgahtori', iid='Samsung Galaxy J3 (8GB)', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Dilip Kumar p', iid='Mi 4i (Grey, 16GB)', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Robk1964', iid='Samsung Galaxy Gio zilver, zwart / 0,158 GB - Overzicht', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='76Hornet76', iid='Samsung Gusto 3 Prepaid No Contract Phone - Retail Packaging (Verizon Wireless)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Shafi H.', iid='BlackBerry Passport (Black, 32GB)', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Tiffany', iid='Samsung Intercept', r_ui=9.0, est=10, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='Michael C.', iid='SAMSUNG Galaxy Nexus Titanium Silver 3G Unlocked GSM Android Smart Phone w/ Android 4.0 / 5 MP Camera / 16GB Internal Memory / NFC (GT-i9250)', r_ui=2.0, est=10, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='francisco javier', iid='Alcatel One Touch 282X - M??vil libre (pantalla de 1,8" 160 x 128), blanco [Importado de Alemania]', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='essie3', iid='Samsung Galaxy Note 3 zwart / 32 GB - Overzicht', r_ui=9.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Britton', iid='Palm Treo 700p', r_ui=5.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Alessandro', iid='Lenovo Motorola Moto G Smartphone, 4,5 pollici display HD, processore Qualcomm, memoria 16GB, MicroSIM, Android 4.3 OS, fotocamera da 5 MP, Nero [Germania]', r_ui=10.0, est=8.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid="Client d'Amazon", iid="Spigen Coque Samsung Galaxy A5 2017, Spigen [Liquid Air] ** Technologie Coussin d'air ** [Noir] Flexible Soft TPU silicone / Nouveau design & Motif unique / Housse Etui Coque Pour Galaxy A5 2017, Samsung A5 2017- (573CS21143)", r_ui=8.0, est=2.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='Kathy G.', iid='Apple iPhone 4S AT&T Cellphone, 16GB, Black', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Appie', iid='Samsung Galaxy S7 Edge wit / 32 GB', r_ui=9.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='sonia', iid='elephone P8000 4G Smartphone MTK6753 64bit Octa Core Touch ID 5,5 Pollici FHD 3GB RAM 16GB ROM 13MP Fotocamera 4165mAh Battery Grigio', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Ð¡ÐµÑ\x80Ð³ÐµÐµÐ²Ð¸Ñ\x87 Ð\x90Ð»ÐµÐºÑ\x81ÐµÐ¹', iid='Sony Xperia Z1 Compact', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Giuseppe P.', iid='Sony Mobile Xperia M4 Aqua Dual Sim (Nero)', r_ui=4.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid
r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='gedeone84', iid='Benefon Twin Dual SIM', r_ui=8.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Beto31 ', iid='Samsung Galaxy S4 16GB (T-Mobile)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='kiki8711', iid='Nokia 6086', r_ui=4.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='sorry if my question is stupid.', iid='Sidekick AT&T QuickFire', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Juan Portillo', iid="Blackview 'Blackview Bv5000 5.0 4 G Outdoor Smartphone IP67 resistente al agua resistente al polvo antigolpes resistente, Android 5.1 doble cÃ¡maras de doble SIM", r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='nen Reiner Zocker', iid='Apple iPhone 3Gs Smartphone (8,9 cm (3,5 Zoll) Display, Touchscreen, 3 Megapixel Kamera, 16GB interne Speicher) schwarz', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='mandre', iid='Alcatel onetouch 991D Smartphone (10,2 cm (4 Zoll) Touchscreen, 3,2 Megapixel Kamera, Dual SIM, Android 2.3) schwarz', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Mace', iid='TigerKing THL W200 MTK6589T 1.5GHz Quad Core 1G RAM+8G ROM Android 4.2 1280*720 Touch Screen GPS WIFI (Black, White)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='e-bit', iid='Smartphone Samsung Galaxy J2 SM-J200M', r_ui=10.0, est=8.4, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='Amandine Chauviteau', iid='Samsung I9195 Galaxy S 4 MINI NFC LTE Smartphone Compact', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Toni L', iid='Acer Liquid E2 Duo - Smartphone libre (pantalla tÃ¡ctil de 4,5", cÃ¡mara 8 Mp, 4 procesadores de 1.2 GHz, 1 GB de RAM, dual SIM), blanco [importado]', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='e-bit', iid='Motorola Moto G 4 XT1626', r_ui=10.0, est=8.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='miatamania', iid='Nokia 5610 Cep Telefonu', r_ui=9.0, est=9.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='JOSE VAZQUEZ', iid='Lenovo A916 4G Unlocked Smartphone (gift-16GB TF Card) 5.5 inch Android 4.4 MT6592M+6290 Octa 8 Core 1.4GHz 1GB 8GB 13MP Dual SIM FDD-LTE & WCDMA & GSM (Black+ 16GB TF Card)', r_ui=6.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Christianne', iid='Honor 6 4G UK Smartphone (5 inch, Touchscreen, Octa-Core, 3GB RAM, 16GB ROM, 13MP rear camera, 5MP front camera, LTE CAT6, Android 4.4, Emotion UI 2.3) White', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='LOVELYJI', iid='Samsung Galaxy J7 Prime', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='sfat', iid='Nokia E5', r_ui=2.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Yngrid Cuesta', iid='BLU Life Pure XL Full HD, 16MP, (32 GB+3GB RAM) - Factory Unlocked ("White")', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='Natalie', iid='BLU Studio 5.5 D610a Unlocked Dual SIM GSM Phone (Pink)', r_ui=10.0, est=8.03376, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  ...]

# %% [markdown]
# ---
#
# ***Q 5. Evaluate the collaborative model. Print RMSE value.***
#
# ***Ans 5.***

# %%
# Calculate RMSE against the test data
print("User-based Collobortive model : validating RMSE using test data")
accuracy.rmse(test_pred, verbose=True)
# Out:
# User-based Collobortive model : validating RMSE using test data
# RMSE: 2.6049
# 2.604856498451057

# %% [markdown]
# ---
#
# ***Q 6.Predict score (average rating) for test users.***
#
# ***Ans 6.***

# %%
 #df_red_sam.to_csv("RecommendationSystem\Phone_reduced_data.csv")

# %%
# Predict score for test user 'Amazon Kunde' who has not predicted Samsung Galaxy Note Edge (Black)
authortest = 'Amazon Kunde'  
producttest = 'Samsung Galaxy Note Edge (Black)'

# %%
predtn = KNN_Mn_algo.predict( authortest, producttest, verbose=True)
# Out:
# user: Amazon Kunde item: Samsung Galaxy Note Edge (Black) r_ui = None   est = 7.58   {'actual_k': 0, 'was_impossible': False}

# %%
authortest = 'e-bit'  
producttest = 'YU Yuphoria YU5010A (Black+Silver)'
predtn = KNN_Mn_algo.predict( authortest, producttest, verbose=True)
# Out:
# user: e-bit      item: YU Yuphoria YU5010A (Black+Silver) r_ui = None   est = 8.86   {'actual_k': 0, 'was_impossible': False}

# %% [markdown]
# ---
#
# ***Q 7. Report your findings and inferences***
#
# ***Ans 7.***

# %% [markdown]
# - The prediction for model provides a common rating when user - item modekl ised than item-item is used
# - The median rating of predicted values are close to 8 rating
# - The input data has same product listed duplicate based on encoded, capacity, color  information and might have skewed the prediction data of a product

# %% [markdown]
# ---
#
# ***Q 8. Try and recommend top 5 products for test users.***
#
# ***Ans 8***
# Authors 'Amazon Kunde'  and 'e-bit' is identified for recommendation

# %%
# Obtain the list of unique products
uniq_prod = df_red_sam['product'].unique( )

# %%
# Get the list of products reviewed by the user Amazon Kunde
user_rev_prod = df_red_sam.loc[ df_red_sam[ 'author' ]=='Amazon Kunde', 'product']

# %%
# remove the rated movies for the recommendations
net_prod_for_recmd = np.setdiff1d( uniq_prod , user_rev_prod )

# %%
top_prod_recmd = []
#Iterate through all the products and predict the score
for prod in net_prod_for_recmd:
    top_prod_recmd.append( ( prod, KNN_Mn_algo.predict(uid='Amazon Kunde', iid=prod ).est ) )

#Sort the predircts for the user Amazon Kunde to display the top 5 products                                             
pd.DataFrame(top_prod_recmd , columns = [ 'Product', 'score' ] ).sort_values( 'score', ascending=False ).head( 5 )
# Out:
#                                                 Product  score
# 4516  Honor 6 - Smartphone libre (pantalla de 5", 16...   10.0
# 8857      Nexus LG Nexus 5 UK Smartphone - White (16GB)   10.0
# 7413  Microsoft Lumia 435 UK SIM-Free Smartphone - B...   10.0
# 300   Acer Liquid E1 Duo Smartphone 11,4 cm (4,5 Zol...   10.0
# 7686                Microsoft Nokia 3510 Handy pleasure   10.0

# %%
# Predict for user e-bit
# Get the list of products reviewed by the user Amazon Kunde
user_rev_prod = df_red_sam.loc[ df_red_sam[ 'author' ]=='e-bit', 'product']

# %%
# remove the rated movies for the recommendations
net_prod_for_recmd = np.setdiff1d( uniq_prod , user_rev_prod )

# %%
top_prod_recmd = []
#Iterate through all the products and predict the score
for prod in net_prod_for_recmd:
    top_prod_recmd.append( ( prod, KNN_Mn_algo.predict(uid='e-bit', iid=prod ).est ) )

#Sort the predircts for the user Amazon Kunde to display the top 5 products                                             
pd.DataFrame(top_prod_recmd , columns = [ 'Product', 'score' ] ).sort_values( 'score', ascending=False ).head( 5 )
# Out:
#                                                  Product     score
# 12150  Samsung Galaxy A3 (2016) - Smartphone de 4.7" ...  9.529570
# 7098   Lenovo Motorola Moto G 4G (2 Generazione) Smar...  9.196237
# 0      (DG300 Versione Aggiornata)5'' DOOGEE VOYAGER2...  8.862903
# 11954  Samsung GALAXY Trend Lite - night black - 3G 4...  8.862903
# 11959         Samsung GOOGLE NEXUS S UNLOCKED CELL PHONE  8.862903

# %% [markdown]
# *** Q 9. Try other techniques (Example: cross validation) to get better results.***
#
# ***Ans 9.***

# %%
from surprise.model_selection import cross_validate

# %%
cross_validate(KNN_Mn_algo, svddata, measures=['RMSE', 'MAE', 'MSE'], cv=3, verbose=True)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE, MSE of algorithm KNNWithMeans on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    2.6059  2.6505  2.6265  2.6276  0.0182
# MAE (testset)     1.9694  2.0029  1.9942  1.9888  0.0142
# MSE (testset)     6.7905  7.0252  6.8985  6.9047  0.0959
# Fit time          11.55   11.52   10.23   11.10   0.62
# Test time         0.18    0.19    0.20    0.19    0.01
# {'test_rmse': array([2.60585342, 2.65050663, 2.62650906]),
#  'test_mae': array([1.96939948, 2.00292833, 1.99419252]),
#  'test_mse': array([6.79047206, 7.0251854 , 6.89854984]),
#  'fit_time': (11.546854734420776, 11.52302861213684, 10.226139783859253),
#  'test_time': (0.18176913261413574, 0.1926116943359375, 0.20339632034301758)}

# %%
# Trying the same using SVD alogorithm
from surprise import SVD
svd_algo = SVD()

# %%
cross_validate(svd_algo, svddata, measures=['RMSE', 'MAE', 'MSE'], cv=3, verbose=True)
# Out:
# Evaluating RMSE, MAE, MSE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    2.5478  2.5326  2.5299  2.5368  0.0079
# MAE (testset)     1.9541  1.9553  1.9462  1.9519  0.0041
# MSE (testset)     6.4915  6.4143  6.4004  6.4354  0.0401
# Fit time          1.71    1.30    1.32    1.44    0.19
# Test time         0.07    0.07    0.15    0.10    0.04
# {'test_rmse': array([2.54784673, 2.53264333, 2.52989227]),
#  'test_mae': array([1.95408467, 1.9553431 , 1.94618482]),
#  'test_mse': array([6.49152296, 6.41428222, 6.40035491]),
#  'fit_time': (1.711954116821289, 1.2959108352661133, 1.3212840557098389),
#  'test_time': (0.07474899291992188, 0.06598663330078125, 0.14551329612731934)}

# %% [markdown]
# ANS: The SVD alogorithm (Fold 1) has a better RMSE compared to KNNWithMeans Algorithm

# %% [markdown]
# ---
#
# ***Q 10. In what business scenario you should use popularity based Recommendation Systems ***
#
# ***Ans 10.***
# Recommendation Systems can be used in
# - Ecommerce Sites that shows recommendation based on product purchased.
# - Entertainment sites that stream media like movies, songs and videos  etc can show recommendations based on popularity especially including cold start sceanrios
# - Financial sites that can recommend products based on volume popularity
# - News ans social modeia sites or apps can recommend news and posts that are most viewed or liked

# %% [markdown]
# ---
#
# ***Q 11. In what business scenario you should use CF based Recommendation Systems***
#
# ***Ans. 11***
#
# The Colorboratie Filtering can be used in
# - Ecommerce sites to recommend based on user-item based coloborative fiktering using items purchased by users having simillar profile or purchase patterns
# - Streaming sites and media sites can recommend movies, songs or videos based on user preferences and simillar users interest in generes
# - Item-item based coloborative fiktering is used to recommend a product that has simillar features against the products previously purchased by the user

# %% [markdown]
# ---
#
# ***Q 12. What other possible methods can you think of which can further improve the recommendation for different users***
#
# ***Ans 12***
#
# The recommendation system should
# - Focus on  recommending selected products that has high sale probability simillar to pareto principle 20% of the products result in 80% of sales
# - Analyze the popularity ratings holoisticly looking at the avg users rated that product and using a threhold limit to avoid small user base rating higher to increase sales dubiously
# - Build related, allied  products or accessory mappings to recommend products that can be be purchased together
